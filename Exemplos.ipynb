# %% [markdown]
# <a href="https://colab.research.google.com/github/GabrielAlbSilv/FMU/blob/main/Exemplos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Conceitos básicos
# Phyton

# %%
#comentario no Phyton
#comando de saída
print("Trabalhando com Python")
print('Novamente imprimindo')
